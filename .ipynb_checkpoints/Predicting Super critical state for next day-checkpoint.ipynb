# %%
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

path =r'C:\Users\Piyushkumar\Documents\GitHub\predictcritical\thermalpower' # use your path
allFiles = glob.glob(path + "/*.csv")
frame = pd.DataFrame()
list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_)

frame.describe(include=['O'])
frame.info()
df= frame.copy()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 121446 entries, 0 to 2669
# Data columns (total 17 columns):
# Date                                   121446 non-null object
# Region                                 121446 non-null object
# Station Name                           121446 non-null object
# Mode of Transport                      121446 non-null object
# Station Name.1                         121446 non-null object
# Utility                                121446 non-null object
# Sector                                 121446 non-null object
# Capacity                               121446 non-null float64
# Normative Stocks Required (In Days)    121446 non-null float64
# Daily Requirement                      121446 non-null float64
# Actual Stock - Import                  121446 non-null float64
# Actual Stock - Indigenous              121446 non-null float64
# Actual Stock - Total                   121446 non-null float64
# Actual Stock - Days                    121446 non-null int64
# Critical                               45318 non-null object
# Super Critical                         25314 non-null object
# Remarks                                30506 non-null object
# dtypes: float64(6), int64(1), object(10)
# memory usage: 12.0+ MB
#          Date    Region Station Name Mode of Transport  Station Name.1  \
# 0  2009-04-01  NORTHERN        DELHI              RAIL    I.P.  T.P.S.
# 1  2009-04-01  NORTHERN        DELHI              RAIL     RAJGHAT TPS
# 2  2009-04-01  NORTHERN        DELHI              RAIL    BADARPUR TPS
# 3  2009-04-01  NORTHERN      HARYANA              RAIL  FARIDABAD TPS.
# 4  2009-04-01  NORTHERN      HARYANA              RAIL     PANIPAT TPS
#
#                                           Utility   Sector  Capacity  \
# 0  INDRAPRASTHA  POWER GENERATION COMPANY LIMITED    STATE     247.5
# 1  INDRAPRASTHA  POWER GENERATION COMPANY LIMITED    STATE     135.0
# 2                                   NTPC LIMITED.  CENTRAL     705.0
# 3   HARYANA POWER  GENERATION CORPORATION LIMITED    STATE      55.0
# 4   HARYANA POWER  GENERATION CORPORATION LIMITED    STATE    1360.0
#
#    Normative Stocks Required (In Days)  Daily Requirement  \
# 0                                 25.0                3.2
# 1                                 25.0                2.2
# 2                                 30.0               13.8
# 3                                 25.0                2.0
# 4                                 25.0               25.0
#
#    Actual Stock - Import  Actual Stock - Indigenous  Actual Stock - Total  \
# 0                    0.0                      57.03                 57.03
# 1                    0.0                     105.08                105.08
# 2                    0.0                      13.17                 13.17
# 3                    0.0                      14.96                 14.96
# 4                    0.0                     111.27                111.27
#
#    Actual Stock - Days  Critical  Super Critical Remarks
# 0                   18       NaN             NaN     NaN
# 1                   48       NaN             NaN     NaN
# 2                    1  Critical  Super Critical     NaN
# 3                    7       NaN             NaN     NaN
# 4                    4  Critical             NaN     NaN

# %%
#df = df.set_index(df['Date'])
#df= df.drop('Date', axis = 1)
all_days = pd.date_range(df.index.min(), df.index.max(), freq='D')
df.head()
df.reset_index(drop=True, inplace=True)

# %%
df.describe(include='all')
df[df.Critical.notnull()].head(5000)[df['Actual Stock - Days'] >= 6]
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# 14890  2010-08-31   WESTERN    CHHATTISGARH              RAIL
# 14897  2010-08-31   WESTERN         GUJARAT              RAIL
# 14911  2010-08-31   WESTERN     MAHARASHTRA              RAIL
# 14948  2010-08-31   EASTERN     WEST BENGAL              RAIL
# 14987  2011-08-01   WESTERN  MADHYA PRADESH              RAIL
# 15023  2011-08-01   EASTERN     WEST BENGAL              RAIL
# 15024  2011-08-01   EASTERN     WEST BENGAL              RAIL
#
#           Station Name.1                                            Utility  \
# 5       YAMUNA NAGAR TPS      HARYANA POWER  GENERATION CORPORATION LIMITED
# 12        HARDUAGANJ TPS   UTTAR PRADESH RAJYA VIDYUT UTPADAN NIGAM LIMITED
# 46       RAYALASEEMA TPS     ANDHRA PRADESH POWER GENERATION CORP. LIMITED.
# 69            D.P.L. TPS                          DURGAPUR PROJECTS LIMITED
# 87       RAYALASEEMA TPS     ANDHRA PRADESH POWER GENERATION CORP. LIMITED.
# 96           BARAUNI TPS                      BIHAR STATE ELECTRICITY BOARD
# 110           D.P.L. TPS                          DURGAPUR PROJECTS LIMITED
# 124     YAMUNA NAGAR TPS      HARYANA POWER  GENERATION CORPORATION LIMITED
# 161     YAMUNA NAGAR TPS      HARYANA POWER  GENERATION CORPORATION LIMITED
# 202      RAYALASEEMA TPS     ANDHRA PRADESH POWER GENERATION CORP. LIMITED.
# 211          BARAUNI TPS                      BIHAR STATE ELECTRICITY BOARD
# 239     YAMUNA NAGAR TPS      HARYANA POWER  GENERATION CORPORATION LIMITED
# 256             KORBA-II       CHHATTISGARH STATE POWER GENERATION CO. LTD.
# 261       SIKKA REP. TPS      GUJARAT STATE ELECTRICITY CORPORATION LIMITED
# 262             UKAI TPS      GUJARAT STATE ELECTRICITY CORPORATION LIMITED
# 280      RAYALASEEMA TPS     ANDHRA PRADESH POWER GENERATION CORP. LIMITED.
# 289          BARAUNI TPS                      BIHAR STATE ELECTRICITY BOARD
# 317     YAMUNA NAGAR TPS      HARYANA POWER  GENERATION CORPORATION LIMITED
# 334             KORBA-II       CHHATTISGARH STATE POWER GENERATION CO. LTD.
# 340             UKAI TPS      GUJARAT STATE ELECTRICITY CORPORATION LIMITED
# 358      RAYALASEEMA TPS     ANDHRA PRADESH POWER GENERATION CORP. LIMITED.
# 412             KORBA-II       CHHATTISGARH STATE POWER GENERATION CO. LTD.
# 417       SIKKA REP. TPS      GUJARAT STATE ELECTRICITY CORPORATION LIMITED
# 418             UKAI TPS      GUJARAT STATE ELECTRICITY CORPORATION LIMITED
# 446      MUZAFFARPUR TPS                    KANTI BIJLEE UTPADAN NIGAM LTD.
# 490             KORBA-II       CHHATTISGARH STATE POWER GENERATION CO. LTD.
# 568             KORBA-II       CHHATTISGARH STATE POWER GENERATION CO. LTD.
# 592      RAYALASEEMA TPS     ANDHRA PRADESH POWER GENERATION CORP. LIMITED.
# 602      MUZAFFARPUR TPS                    KANTI BIJLEE UTPADAN NIGAM LTD.
# 627       FARIDABAD TPS.      HARYANA POWER  GENERATION CORPORATION LIMITED
# ...                  ...                                                ...
# 602                  1.0                   0.00                       6.19
# 627                  2.0                   0.00                      11.99
# ...                  ...                    ...                        ...
# 14181                3.9                   0.00                      22.92
# 14208                5.7                   0.00                      33.44
# 14233                5.7                   0.00                      36.33
# 14240                7.7                   0.00                      50.21
# 14252               12.9                   0.36                      81.21
# 14255               16.8                   0.00                     104.92
# 14288                3.9                   0.00                      24.26
# 14322                7.7                   0.00                      43.52
# 14404                7.7                   0.00                      48.86
# 14419               16.8                   0.00                     101.89
# 14452                3.9                   0.00                      25.15
# 14486                7.7                   0.00                      50.21
# 14501               16.8                   0.00                     101.15
# 14534                3.9                   0.00                      24.49
# 14568                7.7                   0.00                      48.54
# 14583               16.8                   0.00                      93.59
# 14616                3.9                   0.00                      23.94
# 14620                3.7                   0.00                      20.88
# 14698                3.9                   0.00                      24.89
# 14702                3.7                   0.00                      23.66
# 14726                9.7                   0.00                      56.46
# 14782                1.1                   0.00                       6.79
# 14808                9.7                   0.00                      58.77
# 14890                9.7                   0.00                      60.74
# 14897                9.3                  12.21                      44.18
# 14911               16.8                   0.00                      94.66
# 14948                3.7                   0.00                      22.27
# 14987               14.7                   0.00                      90.51
# 15023               14.2                   0.00                      86.29
# 15024                4.0                   0.00                      25.52
#
#        Actual Stock - Total  Actual Stock - Days  Critical Super Critical  \
# 5                     59.82                    6  Critical            NaN
# 12                    16.63                    6  Critical            NaN
# 46                    90.56                    6  Critical            NaN
# 69                    56.95                    6  Critical            NaN
# 87                    93.59                    6  Critical            NaN
# 96                     3.70                    6  Critical            NaN
# 110                   63.79                    6  Critical            NaN
# 124                   56.90                    6  Critical            NaN
# 161                   60.34                    6  Critical            NaN
# 202                   94.05                    6  Critical            NaN
# 211                    3.70                    6  Critical            NaN
# 239                   57.66                    6  Critical            NaN
# 256                   48.72                    6  Critical            NaN
# 261                   25.85                    6  Critical            NaN
# 262                   77.43                    6  Critical            NaN
# 280                   94.48                    6  Critical            NaN
# 289                    3.70                    6  Critical            NaN
# 317                   55.43                    6  Critical            NaN
# 334                   48.52                    6  Critical            NaN
# 340                   74.36                    6  Critical            NaN
# 358                   87.71                    6  Critical            NaN
# 412                   48.73                    6  Critical            NaN
# 417                   26.13                    6  Critical            NaN
# 418                   74.59                    6  Critical            NaN
# 446                    5.89                    6  Critical            NaN
# 490                   48.32                    6  Critical            NaN
# 568                   49.28                    6  Critical            NaN
# 592                   88.98                    6  Critical            NaN
# 602                    6.19                    6  Critical            NaN
# 627                   11.99                    6  Critical            NaN
# ...                     ...                  ...       ...            ...
# 14181                 22.92                    6  Critical            NaN
# 14208                 33.44                    6  Critical            NaN
# 14233                 36.33                    6  Critical            NaN
# 14240                 50.21                    6  Critical            NaN
# 14252                 81.56                    6  Critical            NaN
# 14255                104.92                    6  Critical            NaN
# 14288                 24.26                    6  Critical            NaN
# 14322                 43.52                    6  Critical            NaN
# 14404                 48.86                    6  Critical            NaN
# 14419                101.89                    6  Critical            NaN
# 14452                 25.15                    6  Critical            NaN
# 14486                 50.21                    6  Critical            NaN
# 14501                101.15                    6  Critical            NaN
# 14534                 24.49                    6  Critical            NaN
# 14568                 48.54                    6  Critical            NaN
# 14583                 93.59                    6  Critical            NaN
# 14616                 23.94                    6  Critical            NaN
# 14620                 20.88                    6  Critical            NaN
# 14698                 24.89                    6  Critical            NaN
# 14702                 23.66                    6  Critical            NaN
# 14726                 56.46                    6  Critical            NaN
# 14782                  6.79                    6  Critical            NaN
# 14808                 58.77                    6  Critical            NaN
# 14890                 60.74                    6  Critical            NaN
# 14897                 56.39                    6  Critical            NaN
# 14911                 94.66                    6  Critical            NaN
# 14948                 22.27                    6  Critical            NaN
# 14987                 90.51                    6  Critical            NaN
# 15023                 86.29                    6  Critical            NaN
# 15024                 25.52                    6  Critical            NaN
#
#                    Remarks
# 5                      NaN
# 12                     NaN
# 46                     NaN
# 69                     NaN
# 87                     NaN
# 96                     NaN
# 110                    NaN
# 124                    NaN
# 161                    NaN
# 202                    NaN
# 211                    NaN
# 239                    NaN
# 256                    NaN
# 261                    NaN
# 262                    NaN
# 280                    NaN
# 289                    NaN
# 317                    NaN
# 334                    NaN
# 340                    NaN
# 358                    NaN
# 412                    NaN
# 417                    NaN
# 418                    NaN
# 446                    NaN
# 490                    NaN
# 568    Less Receipt - SECL
# 592     Inadequate linkage
# 602     Inadequate linkage
# 627                    NaN
# ...                    ...
# 14181         Less Receipt
# 14208         Less Receipt
# 14233            No import
# 14240         Less Receipt
# 14252    Higher Generation
# 14255          Less import
# 14288         Less Receipt
# 14322         Less Receipt
# 14404         Less Receipt
# 14419          Less import
# 14452         Less Receipt
# 14486         Less Receipt
# 14501          Less import
# 14534         Less Receipt
# 14568                  NaN
# 14583                  NaN
# 14616                  NaN
# 14620                  NaN
# 14698                  NaN
# 14702                  NaN
# 14726         Less Receipt
# 14782    Higher Generation
# 14808         Less Receipt
# 14890         Less Receipt
# 14897    Higher Generation
# 14911          Less import
# 14948         Less Receipt
# 14987         Less Receipt
# 15023         Less Receipt
# 15024         Less Receipt
#
# [749 rows x 17 columns]

# %%
df[df.Critical.notnull()].head(5000)[df['Actual Stock - Days'] >= 7]
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# Empty DataFrame
# Columns: [Date, Region, Station Name, Mode of Transport, Station Name.1, Utility, Sector, Capacity, Normative Stocks Required (In Days), Daily Requirement, Actual Stock - Import, Actual Stock - Indigenous, Actual Stock - Total, Actual Stock - Days, Critical, Super Critical, Remarks]
# Index: []

# %%
##**A plant is tagged ciritical when the available stock for number of days goes below 7 days**

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Region'] = df['Region'].astype('category')
df['Station Name'] = df['Station Name'].astype('category')
df['Mode of Transport'] = df['Mode of Transport'].astype('category')
df['Station Name.1'] = df['Station Name.1'].astype('category')
df['Utility'] = df['Utility'].astype('category')
df['Sector'] = df['Sector'].astype('category')
df['Critical'] = df['Critical'].map({'Critical': 1})
df['Super Critical'] = df['Super Critical'].map({'Super Critical': 1})
df['Critical'].fillna(value = 0, inplace =True)
df['Super Critical'].fillna(value = 0, inplace =True)
df.describe(include='all')
# Out:
#                        Date   Region Station Name Mode of Transport  \
# count                121446   121446       121446            121446
# unique                 1461        4           16                 4
# top     2012-03-18 00:00:00  EASTERN  WEST BENGAL              RAIL
# freq                     95    35445        19325             91079
# first   2009-01-01 00:00:00      NaN          NaN               NaN
# last    2012-12-31 00:00:00      NaN          NaN               NaN
# mean                    NaN      NaN          NaN               NaN
# std                     NaN      NaN          NaN               NaN
# min                     NaN      NaN          NaN               NaN
# 25%                     NaN      NaN          NaN               NaN
# 50%                     NaN      NaN          NaN               NaN
# 75%                     NaN      NaN          NaN               NaN
# max                     NaN      NaN          NaN               NaN
#
#        Station Name.1        Utility  Sector       Capacity  \
# count          121446         121446  121446  121446.000000
# unique            100             35       4            NaN
# top         ROPAR TPS  NTPC LIMITED.   STATE            NaN
# freq             1461          21900   76107            NaN
# first             NaN            NaN     NaN            NaN
# last              NaN            NaN     NaN            NaN
# mean              NaN            NaN     NaN    1129.157873
# std               NaN            NaN     NaN     803.700708
# min               NaN            NaN     NaN      55.000000
# 25%               NaN            NaN     NaN     500.000000
# 50%               NaN            NaN     NaN    1040.000000
# 75%               NaN            NaN     NaN    1470.000000
# max               NaN            NaN     NaN    4620.000000
#
#         Normative Stocks Required (In Days)  Daily Requirement  \
# count                         121446.000000      121446.000000
# unique                                  NaN                NaN
# top                                     NaN                NaN
# freq                                    NaN                NaN
# first                                   NaN                NaN
# last                                    NaN                NaN
# mean                              22.591906          13.994799
# std                                5.256800          10.880320
# min                               15.000000           0.500000
# 25%                               20.000000           6.400000
# 50%                               20.000000          11.300000
# 75%                               25.000000          18.800000
# max                               30.000000          65.000000
#
#         Actual Stock - Import  Actual Stock - Indigenous  \
# count           121446.000000              121446.000000
# unique                    NaN                        NaN
# top                       NaN                        NaN
# freq                      NaN                        NaN
# first                     NaN                        NaN
# last                      NaN                        NaN
# mean                 3.676711                 133.287357
# std                 15.370966                 140.712095
# min                  0.000000                   0.000000
# 25%                  0.000000                  34.730000
# 50%                  0.000000                  84.610000
# 75%                  0.000000                 184.877500
# max                430.750000                4081.900000
#
#         Actual Stock - Total  Actual Stock - Days       Critical  \
# count          121446.000000        121446.000000  121446.000000
# unique                   NaN                  NaN            NaN
# top                      NaN                  NaN            NaN
# freq                     NaN                  NaN            NaN
# first                    NaN                  NaN            NaN
# last                     NaN                  NaN            NaN
# mean              136.964021            12.348451       0.373154
# std               140.632403            11.547079       0.483644
# min                 0.000000             0.000000       0.000000
# 25%                38.040000             4.000000       0.000000
# 50%                89.560000             9.000000       0.000000
# 75%               189.910000            17.000000       1.000000
# max              4081.900000           324.000000       1.000000
#
#         Super Critical       Remarks
# count    121446.000000         30506
# unique             NaN            70
# top                NaN  Less Receipt
# freq               NaN         11581
# first              NaN           NaN
# last               NaN           NaN
# mean          0.208438           NaN
# std           0.406193           NaN
# min           0.000000           NaN
# 25%           0.000000           NaN
# 50%           0.000000           NaN
# 75%           0.000000           NaN
# max           1.000000           NaN

# %%
df[df.Critical == 1].head(5000)[df['Actual Stock - Days'] >= 7]
values = df[df.Critical == 1]
values.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45318 entries, 2 to 121445
# Data columns (total 17 columns):
# Date                                   45318 non-null datetime64[ns]
# Region                                 45318 non-null category
# Station Name                           45318 non-null category
# Mode of Transport                      45318 non-null category
# Station Name.1                         45318 non-null category
# Utility                                45318 non-null category
# Sector                                 45318 non-null category
# Capacity                               45318 non-null float64
# Normative Stocks Required (In Days)    45318 non-null float64
# Daily Requirement                      45318 non-null float64
# Actual Stock - Import                  45318 non-null float64
# Actual Stock - Indigenous              45318 non-null float64
# Actual Stock - Total                   45318 non-null float64
# Actual Stock - Days                    45318 non-null int64
# Critical                               45318 non-null float64
# Super Critical                         45318 non-null float64
# Remarks                                30151 non-null object
# dtypes: category(6), datetime64[ns](1), float64(8), int64(1), object(1)
# memory usage: 4.2+ MB
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
df.groupby('Station Name.1').tail(5000)
# Out:
#              Date    Region   Station Name Mode of Transport  \
# 0      2009-04-01  NORTHERN          DELHI              RAIL
# 1      2009-04-01  NORTHERN          DELHI              RAIL
# 2      2009-04-01  NORTHERN          DELHI              RAIL
# 3      2009-04-01  NORTHERN        HARYANA              RAIL
# 4      2009-04-01  NORTHERN        HARYANA              RAIL
# 5      2009-04-01  NORTHERN        HARYANA              RAIL
# 6      2009-04-01  NORTHERN         PUNJAB              RAIL
# 7      2009-04-01  NORTHERN         PUNJAB              RAIL
# 8      2009-04-01  NORTHERN         PUNJAB              RAIL
# 9      2009-04-01  NORTHERN      RAJASTHAN              RAIL
# 10     2009-04-01  NORTHERN      RAJASTHAN              RAIL
# 11     2009-04-01  NORTHERN  UTTAR PRADESH           PITHEAD
# 12     2009-04-01  NORTHERN  UTTAR PRADESH              RAIL
# 13     2009-04-01  NORTHERN  UTTAR PRADESH              RAIL
# 14     2009-04-01  NORTHERN  UTTAR PRADESH              RAIL
# 15     2009-04-01  NORTHERN  UTTAR PRADESH              RAIL
# 16     2009-04-01  NORTHERN  UTTAR PRADESH              RAIL
# 17     2009-04-01  NORTHERN  UTTAR PRADESH           PITHEAD
# 18     2009-04-01  NORTHERN  UTTAR PRADESH           PITHEAD
# 19     2009-04-01  NORTHERN  UTTAR PRADESH              RAIL
# 20     2009-04-01  NORTHERN  UTTAR PRADESH              RAIL
# 21     2009-04-01   WESTERN   CHHATTISGARH              RAIL
# 22     2009-04-01   WESTERN   CHHATTISGARH           PITHEAD
# 23     2009-04-01   WESTERN   CHHATTISGARH           PITHEAD
# 24     2009-04-01   WESTERN   CHHATTISGARH           PITHEAD
# 25     2009-04-01   WESTERN   CHHATTISGARH           PITHEAD
# 26     2009-04-01   WESTERN        GUJARAT              RAIL
# 27     2009-04-01   WESTERN        GUJARAT              RAIL
# 28     2009-04-01   WESTERN        GUJARAT              RAIL
# 29     2009-04-01   WESTERN        GUJARAT              RAIL
# ...           ...       ...            ...               ...
# 121416 2012-09-30  SOUTHERN     TAMIL NADU       INTER MODAL
# 121417 2012-09-30  SOUTHERN     TAMIL NADU       INTER MODAL
# 121418 2012-09-30  SOUTHERN     TAMIL NADU       INTER MODAL
# 121419 2012-09-30   EASTERN          BIHAR              RAIL
# 121420 2012-09-30   EASTERN          BIHAR              RAIL
# 121421 2012-09-30   EASTERN          BIHAR           PITHEAD
# 121428       ORISSA POWER GENERATION CORPORATION LIMITED    STATE     420.0
# 121429                                     NTPC LIMITED.  CENTRAL     470.0
# 121430                                     NTPC LIMITED.  CENTRAL    3000.0
# 121431                           STERLITE ENERGY LIMITED      IPP    2400.0
# 121432                        DAMODAR VALLEY CORPORATION  CENTRAL     340.0
# 121433                        DAMODAR VALLEY CORPORATION  CENTRAL    2340.0
# 121434       WEST BENGAL POWER DEVELOPMENT CORP. LIMITED    STATE    1050.0
# 121435       WEST BENGAL POWER DEVELOPMENT CORP. LIMITED    STATE     450.0
# 121436                         DURGAPUR PROJECTS LIMITED    STATE     630.0
# 121437       WEST BENGAL POWER DEVELOPMENT CORP. LIMITED    STATE    1260.0
# 121438       WEST BENGAL POWER DEVELOPMENT CORP. LIMITED    STATE     600.0
# 121439       WEST BENGAL POWER DEVELOPMENT CORP. LIMITED    STATE     980.0
# 121440                 CALCUTTA ELECTRIC SUPPLY CO. LTD.  PRIVATE     750.0
# 121441                 CALCUTTA ELECTRIC SUPPLY CO. LTD.  PRIVATE     160.0
# 121442                 CALCUTTA ELECTRIC SUPPLY CO. LTD.  PRIVATE     135.0
# 121443                 CALCUTTA ELECTRIC SUPPLY CO. LTD.  PRIVATE     240.0
# 121444                                     NTPC LIMITED.  CENTRAL    2100.0
# 121445                        DAMODAR VALLEY CORPORATION  CENTRAL    1000.0
#
#         Normative Stocks Required (In Days)  Daily Requirement  \
# 0                                      25.0                3.2
# 1                                      25.0                2.2
# 2                                      30.0               13.8
# 3                                      25.0                2.0
# 4                                      25.0               25.0
# 5                                      25.0               10.0
# 6                                      30.0               14.5
# 7                                      30.0                6.5
# 8                                      30.0               20.7
# 9                                      30.0               20.2
# 10                                     30.0               25.2
# 11                                     15.0               26.7
# 12                                     25.0                3.0
# 13                                     20.0               15.0
# 14                                     30.0                4.0
# 15                                     30.0               11.7
# 16                                     30.0               15.0
# 17                                     15.0               35.7
# 18                                     15.0               32.0
# 19                                     25.0                8.3
# 20                                     25.0               20.0
# 21                                     15.0                9.0
# 22                                     15.0                8.0
# 23                                     15.0               12.3
# 24                                     15.0               32.0
# 25                                     20.0               15.7
# 26                                     30.0               12.7
# 27                                     30.0                4.3
# 28                                     30.0               13.0
# 29                                     30.0               24.0
# ...                                     ...                ...
# 121416                                 30.0               13.4
# 121417                                 30.0                8.0
# 121418                                 30.0               14.2
# 121419                                 20.0                0.5
# 121420                                 20.0                1.0
# 121421                                 15.0               30.6
# 121422                                 20.0                1.5
# 121423                                 20.0                3.7
# 121424                                 20.0                7.3
# 121425                                 20.0               12.2
# 121426                                 20.0               11.0
# 121427                                 20.0                6.8
# 121428                                 15.0                6.1
# 121429                                 15.0                6.8
# 121430                                 15.0               42.8
# 121431                                 20.0               19.6
# 121432                                 20.0                3.7
# 121433                                 20.0               19.6
# 121434                                 25.0               13.2
# 121435                                 20.0                3.7
# 121436                                 25.0                5.4
# 121437                                 25.0               14.7
# 121438                                 20.0                6.1
# 121439                                 20.0                4.9
# 121440                                 20.0                8.1
# 26                    103.04                    8       0.0             0.0
# 27                     28.39                    7       0.0             0.0
# 28                     85.28                    7       0.0             0.0
# 29                     78.77                    3       1.0             1.0
# ...                      ...                  ...       ...             ...
# 121416                194.59                   14       0.0             0.0
# 121417                 63.27                    8       0.0             0.0
# 121418                153.98                   11       0.0             0.0
# 121419                  9.19                   18       0.0             0.0
# 121420                  3.31                    3       1.0             1.0
# 121421                104.37                    3       1.0             1.0
# 121422                 84.05                   57       0.0             0.0
# 121423                119.42                   33       0.0             0.0
# 121424                  8.18                    1       1.0             1.0
# 121425                100.08                    8       0.0             0.0
# 121426                179.04                   16       0.0             0.0
# 121427                  0.00                    0       1.0             1.0
# 121428                 75.46                   12       0.0             0.0
# 121429                 93.27                   14       0.0             0.0
# 121430                 76.66                    2       1.0             1.0
# 121431                 49.84                    3       1.0             1.0
# 121432                251.44                   69       0.0             0.0
# 121433                182.36                    9       0.0             0.0
# 121434                 21.04                    2       1.0             1.0
# 121435                 43.14                   12       0.0             0.0
# 121436                 10.28                    2       1.0             1.0
# 121437                 66.92                    5       1.0             0.0
# 121438                 93.01                   15       0.0             0.0
# 121439                 27.80                    6       1.0             0.0
# 121440                147.74                   18       0.0             0.0
# 121441                 11.59                   11       0.0             0.0
# 121442                 24.58                   12       0.0             0.0
# 121443                 22.89                    7       0.0             0.0
# 121444                 33.73                    1       1.0             1.0
# 121445                  8.70                    1       1.0             1.0
#
#                              Remarks
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 6                                NaN
# 7                                NaN
# 8                                NaN
# 9                                NaN
# 10                               NaN
# 11                               NaN
# 12                               NaN
# 13                               NaN
# 14                               NaN
# 15                               NaN
# 16                               NaN
# 17                               NaN
# 18                               NaN
# 19                               NaN
# 20                               NaN
# 21                               NaN
# 22                               NaN
# 23                               NaN
# 24                               NaN
# 25                               NaN
# 26                               NaN
# 27                               NaN
# 28                               NaN
# 29                               NaN
# ...                              ...
# 121416                           NaN
# 121417                           NaN
# 121418                           NaN
# 121419                           NaN
# 121420                Under Shutdown
# 121421  Inadequate coal availability
# 121422                           NaN
# 121423                           NaN
# 121424                  Less Receipt
# 121425                           NaN
# 121426                           NaN
# 121427       Coal supp. yet to start
# 121428                           NaN
# 121429                           NaN
# 121430                  Less Receipt
# 121431                  Less Receipt
# 121432                           NaN
# 121433                           NaN
# 121434                  Less Receipt
# 121435                           NaN
# 121436                  Less Receipt
# 121437                   Less import
# 121438                           NaN
# 121439                   Less import
# 121440                           NaN
# 121441                           NaN
# 121442                           NaN
# 121443                           NaN
# 121444  Inadequate coal availability
# 121445                  Less Receipt
#
# [121446 rows x 17 columns]

# %%
df[df.Critical.isnull()].head()
# Out:
# Empty DataFrame
# Columns: [Date, Region, Station Name, Mode of Transport, Station Name.1, Utility, Sector, Capacity, Normative Stocks Required (In Days), Daily Requirement, Actual Stock - Import, Actual Stock - Indigenous, Actual Stock - Total, Actual Stock - Days, Critical, Super Critical, Remarks]
# Index: []

# %%
df.set_index(df['Date'], inplace=True)
df.head()
# Out:
#                  Date    Region Station Name Mode of Transport  \
# Date
# 2009-04-01 2009-04-01  NORTHERN        DELHI              RAIL
# 2009-04-01 2009-04-01  NORTHERN        DELHI              RAIL
# 2009-04-01 2009-04-01  NORTHERN        DELHI              RAIL
# 2009-04-01 2009-04-01  NORTHERN      HARYANA              RAIL
# 2009-04-01 2009-04-01  NORTHERN      HARYANA              RAIL
#
#             Station Name.1                                         Utility  \
# Date
# 2009-04-01    I.P.  T.P.S.  INDRAPRASTHA  POWER GENERATION COMPANY LIMITED
# 2009-04-01     RAJGHAT TPS  INDRAPRASTHA  POWER GENERATION COMPANY LIMITED
# 2009-04-01    BADARPUR TPS                                   NTPC LIMITED.
# 2009-04-01  FARIDABAD TPS.   HARYANA POWER  GENERATION CORPORATION LIMITED
# 2009-04-01     PANIPAT TPS   HARYANA POWER  GENERATION CORPORATION LIMITED
#
#              Sector  Capacity  Normative Stocks Required (In Days)  \
# Date
# 2009-04-01    STATE     247.5                                 25.0
# 2009-04-01    STATE     135.0                                 25.0
# 2009-04-01  CENTRAL     705.0                                 30.0
# 2009-04-01    STATE      55.0                                 25.0
# 2009-04-01    STATE    1360.0                                 25.0
#
#             Daily Requirement  Actual Stock - Import  \
# Date
# 2009-04-01                3.2                    0.0
# 2009-04-01                2.2                    0.0
# 2009-04-01               13.8                    0.0
# 2009-04-01                2.0                    0.0
# 2009-04-01               25.0                    0.0
#
#             Actual Stock - Indigenous  Actual Stock - Total  \
# Date
# 2009-04-01                      57.03                 57.03
# 2009-04-01                     105.08                105.08
# 2009-04-01                      13.17                 13.17
# 2009-04-01                      14.96                 14.96
# 2009-04-01                     111.27                111.27
#
#             Actual Stock - Days  Critical  Super Critical Remarks
# Date
# 2009-04-01                   18       0.0             0.0     NaN
# 2009-04-01                   48       0.0             0.0     NaN
# 2009-04-01                    1       1.0             1.0     NaN
# 2009-04-01                    7       0.0             0.0     NaN
# 2009-04-01                    4       1.0             0.0     NaN

# %%
df.drop('Date',axis =1, inplace =True)
df.head()
# Out:
#               Region Station Name Mode of Transport  Station Name.1  \
# Date
# 2009-04-01  NORTHERN        DELHI              RAIL    I.P.  T.P.S.
# 2009-04-01  NORTHERN        DELHI              RAIL     RAJGHAT TPS
# 2009-04-01  NORTHERN        DELHI              RAIL    BADARPUR TPS
# 2009-04-01  NORTHERN      HARYANA              RAIL  FARIDABAD TPS.
# 2009-04-01  NORTHERN      HARYANA              RAIL     PANIPAT TPS
#
#                                                    Utility   Sector  Capacity  \
# Date
# 2009-04-01  INDRAPRASTHA  POWER GENERATION COMPANY LIMITED    STATE     247.5
# 2009-04-01  INDRAPRASTHA  POWER GENERATION COMPANY LIMITED    STATE     135.0
# 2009-04-01                                   NTPC LIMITED.  CENTRAL     705.0
# 2009-04-01   HARYANA POWER  GENERATION CORPORATION LIMITED    STATE      55.0
# 2009-04-01   HARYANA POWER  GENERATION CORPORATION LIMITED    STATE    1360.0
#
#             Normative Stocks Required (In Days)  Daily Requirement  \
# Date
# 2009-04-01                                 25.0                3.2
# 2009-04-01                                 25.0                2.2
# 2009-04-01                                 30.0               13.8
# 2009-04-01                                 25.0                2.0
# 2009-04-01                                 25.0               25.0
#
#             Actual Stock - Import  Actual Stock - Indigenous  \
# Date
# 2009-04-01                    0.0                      57.03
# 2009-04-01                    0.0                     105.08
# 2009-04-01                    0.0                      13.17
# 2009-04-01                    0.0                      14.96
# 2009-04-01                    0.0                     111.27
#
#             Actual Stock - Total  Actual Stock - Days  Critical  \
# Date
# 2009-04-01                 57.03                   18       0.0
# 2009-04-01                105.08                   48       0.0
# 2009-04-01                 13.17                    1       1.0
# 2009-04-01                 14.96                    7       0.0
# 2009-04-01                111.27                    4       1.0
#
#             Super Critical Remarks
# Date
# 2009-04-01             0.0     NaN
# 2009-04-01             0.0     NaN
# 2009-04-01             1.0     NaN
# 2009-04-01             0.0     NaN
# 2009-04-01             0.0     NaN

# %%
def reindex_by_date(df):
    dates = pd.date_range(df.index.min(), df.index.max())
    return df.reindex(dates).fillna(method ='ffill' )

df1 = df.groupby('Station Name.1').apply(reindex_by_date)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 121887 entries, (AMAR KANTAK, 2009-01-01 00:00:00) to (YAMUNA NAGAR TPS, 2012-12-31 00:00:00)
# Data columns (total 16 columns):
# Region                                 121887 non-null category
# Station Name                           121887 non-null category
# Mode of Transport                      121887 non-null category
# Station Name.1                         121887 non-null category
# Utility                                121887 non-null category
# Sector                                 121887 non-null category
# Capacity                               121887 non-null float64
# Normative Stocks Required (In Days)    121887 non-null float64
# Daily Requirement                      121887 non-null float64
# Actual Stock - Import                  121887 non-null float64
# Actual Stock - Indigenous              121887 non-null float64
# Actual Stock - Total                   121887 non-null float64
# Actual Stock - Days                    121887 non-null float64
# Critical                               121887 non-null float64
# Super Critical                         121887 non-null float64
# Remarks                                113378 non-null object
# dtypes: category(6), float64(9), object(1)
# memory usage: 9.9+ MB

# %%
#df1.drop('Date',axis =1, inplace=True)
df1.drop('Station Name.1',axis =1, inplace=True)
df1 = df1.reset_index()

# %%
df1.describe(include='all')
# Out:
#           Station Name.1              level_1   Region Station Name  \
# count             121887               121887   121887       121887
# unique               100                 1461        4           16
# top     YAMUNA NAGAR TPS  2012-03-26 00:00:00  EASTERN  WEST BENGAL
# freq                1461                   95    35625        19434
# first                NaN  2009-01-01 00:00:00      NaN          NaN
# last                 NaN  2012-12-31 00:00:00      NaN          NaN
# mean                 NaN                  NaN      NaN          NaN
# std                  NaN                  NaN      NaN          NaN
# min                  NaN                  NaN      NaN          NaN
# 25%                  NaN                  NaN      NaN          NaN
# 50%                  NaN                  NaN      NaN          NaN
# 75%                  NaN                  NaN      NaN          NaN
# max                  NaN                  NaN      NaN          NaN
#
#        Mode of Transport        Utility  Sector       Capacity  \
# count             121887         121887  121887  121887.000000
# unique                 4             35       4            NaN
# top                 RAIL  NTPC LIMITED.   STATE            NaN
# freq               91480          21915   76329            NaN
# first                NaN            NaN     NaN            NaN
# last                 NaN            NaN     NaN            NaN
# mean                 NaN            NaN     NaN    1128.054308
# std                  NaN            NaN     NaN     803.338267
# min                  NaN            NaN     NaN      55.000000
# 25%                  NaN            NaN     NaN     500.000000
# 50%                  NaN            NaN     NaN    1040.000000
# 75%                  NaN            NaN     NaN    1470.000000
# max                  NaN            NaN     NaN    4620.000000
#
#         Normative Stocks Required (In Days)  Daily Requirement  \
# count                         121887.000000      121887.000000
# unique                                  NaN                NaN
# top                                     NaN                NaN
# freq                                    NaN                NaN
# first                                   NaN                NaN
# last                                    NaN                NaN
# mean                              22.592193          13.979022
# std                                5.252886          10.873091
# min                               15.000000           0.500000
# 25%                               20.000000           6.400000
# 50%                               20.000000          11.300000
# 75%                               25.000000          18.800000
# max                               30.000000          65.000000
#
#         Actual Stock - Import  Actual Stock - Indigenous  \
# count           121887.000000              121887.000000
# unique                    NaN                        NaN
# top                       NaN                        NaN
# freq                      NaN                        NaN
# first                     NaN                        NaN
# last                      NaN                        NaN
# mean                 3.665533                 133.133679
# std                 15.346892                 140.605019
# min                  0.000000                   0.000000
# 25%                  0.000000                  34.720000
# 50%                  0.000000                  84.420000
# 75%                  0.000000                 184.600000
# max                430.750000                4081.900000
#
#         Actual Stock - Total  Actual Stock - Days       Critical  \
# count          121887.000000        121887.000000  121887.000000
# unique                   NaN                  NaN            NaN
# top                      NaN                  NaN            NaN
# freq                     NaN                  NaN            NaN
# first                    NaN                  NaN            NaN
# last                     NaN                  NaN            NaN
# mean              136.799165            12.345697       0.373174
# std               140.530827            11.550393       0.483650
# min                 0.000000             0.000000       0.000000
# 25%                38.030000             4.000000       0.000000
# 50%                89.350000             9.000000       0.000000
# 75%               189.700000            17.000000       1.000000
# max              4081.900000           324.000000       1.000000
#
#         Super Critical       Remarks
# count    121887.000000        113378
# unique             NaN            70
# top                NaN  Less Receipt
# freq               NaN         45010
# first              NaN           NaN
# last               NaN           NaN
# mean          0.208464           NaN
# std           0.406212           NaN
# min           0.000000           NaN
# 25%           0.000000           NaN
# 50%           0.000000           NaN
# 75%           0.000000           NaN
# max           1.000000           NaN

# %%
values = df1[df1.Critical == 1]
values.info()
# There were 45318 critical incidents before adding missing dates and doing forward fill. Now we have 45485 critical incidents.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45485 entries, 151 to 121758
# Data columns (total 17 columns):
# Station Name.1                         45485 non-null category
# level_1                                45485 non-null datetime64[ns]
# Region                                 45485 non-null category
# Station Name                           45485 non-null category
# Mode of Transport                      45485 non-null category
# Utility                                45485 non-null category
# Sector                                 45485 non-null category
# Capacity                               45485 non-null float64
# Normative Stocks Required (In Days)    45485 non-null float64
# Daily Requirement                      45485 non-null float64
# Actual Stock - Import                  45485 non-null float64
# Actual Stock - Indigenous              45485 non-null float64
# Actual Stock - Total                   45485 non-null float64
# Actual Stock - Days                    45485 non-null float64
# Critical                               45485 non-null float64
# Super Critical                         45485 non-null float64
# Remarks                                45392 non-null object
# dtypes: category(6), datetime64[ns](1), float64(9), object(1)
# memory usage: 4.3+ MB

# %%
df1[df1.Critical == 1][df1['Actual Stock - Days'] >7]
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# Empty DataFrame
# Columns: [Station Name.1, level_1, Region, Station Name, Mode of Transport, Utility, Sector, Capacity, Normative Stocks Required (In Days), Daily Requirement, Actual Stock - Import, Actual Stock - Indigenous, Actual Stock - Total, Actual Stock - Days, Critical, Super Critical, Remarks]
# Index: []

# %%
df1.describe(include='all')
# Out:
#           Station Name.1              level_1   Region Station Name  \
# count             121887               121887   121887       121887
# unique               100                 1461        4           16
# top     YAMUNA NAGAR TPS  2012-03-26 00:00:00  EASTERN  WEST BENGAL
# freq                1461                   95    35625        19434
# first                NaN  2009-01-01 00:00:00      NaN          NaN
# last                 NaN  2012-12-31 00:00:00      NaN          NaN
# mean                 NaN                  NaN      NaN          NaN
# std                  NaN                  NaN      NaN          NaN
# min                  NaN                  NaN      NaN          NaN
# 25%                  NaN                  NaN      NaN          NaN
# 50%                  NaN                  NaN      NaN          NaN
# 75%                  NaN                  NaN      NaN          NaN
# max                  NaN                  NaN      NaN          NaN
#
#        Mode of Transport        Utility  Sector       Capacity  \
# count             121887         121887  121887  121887.000000
# unique                 4             35       4            NaN
# top                 RAIL  NTPC LIMITED.   STATE            NaN
# freq               91480          21915   76329            NaN
# first                NaN            NaN     NaN            NaN
# last                 NaN            NaN     NaN            NaN
# mean                 NaN            NaN     NaN    1128.054308
# std                  NaN            NaN     NaN     803.338267
# min                  NaN            NaN     NaN      55.000000
# 25%                  NaN            NaN     NaN     500.000000
# 50%                  NaN            NaN     NaN    1040.000000
# 75%                  NaN            NaN     NaN    1470.000000
# max                  NaN            NaN     NaN    4620.000000
#
#         Normative Stocks Required (In Days)  Daily Requirement  \
# count                         121887.000000      121887.000000
# unique                                  NaN                NaN
# top                                     NaN                NaN
# freq                                    NaN                NaN
# first                                   NaN                NaN
# last                                    NaN                NaN
# mean                              22.592193          13.979022
# std                                5.252886          10.873091
# min                               15.000000           0.500000
# 25%                               20.000000           6.400000
# 50%                               20.000000          11.300000
# 75%                               25.000000          18.800000
# max                               30.000000          65.000000
#
#         Actual Stock - Import  Actual Stock - Indigenous  \
# count           121887.000000              121887.000000
# unique                    NaN                        NaN
# top                       NaN                        NaN
# freq                      NaN                        NaN
# first                     NaN                        NaN
# last                      NaN                        NaN
# mean                 3.665533                 133.133679
# std                 15.346892                 140.605019
# min                  0.000000                   0.000000
# 25%                  0.000000                  34.720000
# 50%                  0.000000                  84.420000
# 75%                  0.000000                 184.600000
# max                430.750000                4081.900000
#
#         Actual Stock - Total  Actual Stock - Days       Critical  \
# count          121887.000000        121887.000000  121887.000000
# unique                   NaN                  NaN            NaN
# top                      NaN                  NaN            NaN
# freq                     NaN                  NaN            NaN
# first                    NaN                  NaN            NaN
# last                     NaN                  NaN            NaN
# mean              136.799165            12.345697       0.373174
# std               140.530827            11.550393       0.483650
# min                 0.000000             0.000000       0.000000
# 25%                38.030000             4.000000       0.000000
# 50%                89.350000             9.000000       0.000000
# 75%               189.700000            17.000000       1.000000
# max              4081.900000           324.000000       1.000000
#
#         Super Critical       Remarks
# count    121887.000000        113378
# unique             NaN            70
# top                NaN  Less Receipt
# freq               NaN         45010
# first              NaN           NaN
# last               NaN           NaN
# mean          0.208464           NaN
# std           0.406212           NaN
# min           0.000000           NaN
# 25%           0.000000           NaN
# 50%           0.000000           NaN
# 75%           0.000000           NaN
# max           1.000000           NaN

# %%
value = df1['Actual Stock - Total'] - df1['Actual Stock - Import'] - df1['Actual Stock - Indigenous']
value.describe()
# Out:
# count    121887.000000
# mean         -0.000046
# std           0.001664
# min          -0.010000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max
# 21                 16.0       0.0             0.0     NaN
# 22                 16.0       0.0             0.0     NaN
# 23                 16.0       0.0             0.0     NaN
# 24                 16.0       0.0             0.0     NaN
# 25                 16.0       0.0             0.0     NaN
# 26                 16.0       0.0             0.0     NaN
# 27                 16.0       0.0             0.0     NaN
# 28                 16.0       0.0             0.0     NaN
# 29                 16.0       0.0             0.0     NaN
# 30                 16.0       0.0             0.0     NaN
# 31                 14.0       0.0             0.0     NaN
# 32                 14.0       0.0             0.0     NaN
# 33                 14.0       0.0             0.0     NaN
# 34                 14.0       0.0             0.0     NaN
# 35                 14.0       0.0             0.0     NaN
# 36                 14.0       0.0             0.0     NaN
# 37                 15.0       0.0             0.0     NaN
# 38                 15.0       0.0             0.0     NaN
# 39                 15.0       0.0             0.0     NaN
# 40                 15.0       0.0             0.0     NaN
# 41                 15.0       0.0             0.0     NaN
# 42                 15.0       0.0             0.0     NaN
# 43                 15.0       0.0             0.0     NaN
# 44                 15.0       0.0             0.0     NaN
# 45                 15.0       0.0             0.0     NaN
# 46                 15.0       0.0             0.0     NaN
# 47                 15.0       0.0             0.0     NaN
# 48                 15.0       0.0             0.0     NaN
# 49                 15.0       0.0             0.0     NaN

# %%
sns.lmplot('Capacity', 'Daily Requirement',
           data=df1,
           fit_reg=False,
           hue="Region"
          )
plt.show()

# %%
sns.lmplot('Daily Requirement', 'Actual Stock - Total',
           data=df1,
           fit_reg=False,
           hue="Critical"
          )
plt.show()

# %%
sns.lmplot('Actual Stock - Import', 'Actual Stock - Indigenous',
           data=df1,
           fit_reg=False,
           hue="Critical"
          )
plt.show()

# %%
sns.stripplot(x="Mode of Transport", y="Normative Stocks Required (In Days)", data=df1);
plt.show()

# %%
sns.violinplot(y="Mode of Transport", x="Daily Requirement", data=df1, hue='Critical', split = True);
plt.show()

# %%
sns.violinplot(y="Sector", x="Daily Requirement", data=df1, hue='Critical', split = True);
plt.show()

# %%
sns.violinplot(y="Station Name", x="Daily Requirement", data=df1, hue='Critical', split = True);
plt.show()

# %%
df1['Daily_Percent']=(df1['Daily Requirement']/df1.Capacity)*100
df1['Indigenous_Percent'] = (df1['Actual Stock - Indigenous']/df1.Capacity)*100
df1['Import_Percent'] = (df1['Actual Stock - Import']/df1.Capacity)*100
df1['Total_Percent'] = (df1['Actual Stock - Total']/df1.Capacity)*100

# %%
df1.head()
# Out:
#   Station Name.1    level_1   Region    Station Name Mode of Transport  \
# 0    AMAR KANTAK 2009-01-01  WESTERN  MADHYA PRADESH           PITHEAD
# 1    AMAR KANTAK 2009-01-02  WESTERN  MADHYA PRADESH           PITHEAD
# 2    AMAR KANTAK 2009-01-03  WESTERN  MADHYA PRADESH           PITHEAD
# 3    AMAR KANTAK 2009-01-04  WESTERN  MADHYA PRADESH           PITHEAD
# 4    AMAR KANTAK 2009-01-05  WESTERN  MADHYA PRADESH           PITHEAD
#
#                                       Utility Sector  Capacity  \
# 0  M. P. POWER GENERATING CORPORATION LIMITED  STATE     490.0
# 1  M. P. POWER GENERATING CORPORATION LIMITED  STATE     490.0
# 2  M. P. POWER GENERATING CORPORATION LIMITED  STATE     490.0
# 3  M. P. POWER GENERATING CORPORATION LIMITED  STATE     490.0
# 4  M. P. POWER GENERATING CORPORATION LIMITED  STATE     490.0
#
#    Normative Stocks Required (In Days)  Daily Requirement      ...        \
# 0                                 15.0                5.7      ...
# 1                                 15.0                5.7      ...
# 2                                 15.0                5.7      ...
# 3                                 15.0                5.7      ...
# 4                                 15.0                5.7      ...
#
#    Actual Stock - Indigenous  Actual Stock - Total  Actual Stock - Days  \
# 0                     102.44                102.44                 18.0
# 1                     102.44                102.44                 18.0
# 2                     102.37                102.37                 18.0
# 3                     102.65                102.65                 18.0
# 4                     102.15                102.15                 18.0
#
#    Critical  Super Critical  Remarks Daily_Percent  Indigenous_Percent  \
# 0       0.0             0.0      NaN      1.163265           20.906122
# 1       0.0             0.0      NaN      1.163265           20.906122
# 2       0.0             0.0      NaN      1.163265           20.891837
# 3       0.0             0.0      NaN      1.163265           20.948980
# 4       0.0             0.0      NaN      1.163265           20.846939
#
#    Import_Percent  Total_Percent
# 0             0.0      20.906122
# 1             0.0      20.906122
# 2             0.0      20.891837
# 3             0.0      20.948980
# 4             0.0      20.846939
#
# [5 rows x 21 columns]

# %%
sns.lmplot('Daily_Percent', 'Indigenous_Percent',
           data=df1,
           fit_reg=False,
           hue="Critical"
          )
plt.show()

# %%
sns.lmplot('Import_Percent', 'Daily_Percent',
           data=df1,
           fit_reg=False,
           hue="Critical"
          )
plt.show()

# %%
sns.lmplot('Total_Percent', 'Daily_Percent',
           data=df1,
           fit_reg=False,
           hue="Critical"
          )
plt.show()

# %%
def change_critical_value(daf):
    daf.Critical = daf.Critical.shift(-1) ## shift up
    #daf.Critical.drop(daf.Critical.shape[0] - 1,inplace = True) ## removing the last row
    return daf

df2 = df1.groupby('Station Name.1').apply(change_critical_value)

# %%
values = df2[df2.Critical == 1]
values.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45426 entries, 150 to 121757
# Data columns (total 21 columns):
# Station Name.1                         45426 non-null category
# level_1                                45426 non-null datetime64[ns]
# Region                                 45426 non-null category
# Station Name                           45426 non-null category
# Mode of Transport                      45426 non-null category
# Utility                                45426 non-null category
# Sector                                 45426 non-null category
# Capacity                               45426 non-null float64
# Normative Stocks Required (In Days)    45426 non-null float64
# Daily Requirement                      45426 non-null float64
# Actual Stock - Import                  45426 non-null float64
# Actual Stock - Indigenous              45426 non-null float64
# Actual Stock - Total                   45426 non-null float64
# Actual Stock - Days                    45426 non-null float64
# Critical                               45426 non-null float64
# Super Critical                         45426 non-null float64
# Remarks                                45298 non-null object
# Daily_Percent                          45426 non-null float64
# Indigenous_Percent                     45426 non-null float64
# Import_Percent                         45426 non-null float64
# Total_Percent                          45426 non-null float64
# dtypes: category(6), datetime64[ns](1), float64(13), object(1)
# memory usage: 5.6+ MB

# %%
df2.Critical.fillna(0, inplace=True)

# %%
values = df2[df2.Critical == 1]
values.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45426 entries, 150 to 121757
# Data columns (total 21 columns):
# Station Name.1                         45426 non-null category
# level_1                                45426 non-null datetime64[ns]
# Region                                 45426 non-null category
# Station Name                           45426 non-null category
# Mode of Transport                      45426 non-null category
# Utility                                45426 non-null category
# Sector                                 45426 non-null category
# Capacity                               45426 non-null float64
# Normative Stocks Required (In Days)    45426 non-null float64
# Daily Requirement                      45426 non-null float64
# Actual Stock - Import                  45426 non-null float64
# Actual Stock - Indigenous              45426 non-null float64
# Actual Stock - Total                   45426 non-null float64
# Actual Stock - Days                    45426 non-null float64
# Critical                               45426 non-null float64
# Super Critical                         45426 non-null float64
# Remarks                                45298 non-null object
# Daily_Percent                          45426 non-null float64
# Indigenous_Percent                     45426 non-null float64
# Import_Percent                         45426 non-null float64
# Total_Percent                          45426 non-null float64
# dtypes: category(6), datetime64[ns](1), float64(13), object(1)
# memory usage: 5.6+ MB

# %%
labels = df2['Critical']
features= df2.drop(['Total_Percent','Critical','Daily Requirement', 'Actual Stock - Indigenous', 'Actual Stock - Total', 'Actual Stock - Import', 'Super Critical','Remarks'], axis=1)

# %%
cat_col = df.select_dtypes(['category']).columns
features[cat_col] = features[cat_col].apply(lambda x: x.cat.codes)

# %%
features.set_index('level_1', inplace=True)
features.head()
# Out:
#             Station Name.1  Region  Station Name  Mode of Transport  Utility  \
# level_1
# 2009-01-01               0       3             8                  1       18
# 2009-01-02               0       3             8                  1       18
# 2009-01-03               0       3             8                  1       18
# 2009-01-04               0       3             8                  1       18
# 2009-01-05               0       3             8                  1       18
#
#             Sector  Capacity  Normative Stocks Required (In Days)  \
# level_1
# 2009-01-01       3     490.0                                 15.0
# 2009-01-02       3     490.0                                 15.0
# 2009-01-03       3     490.0                                 15.0
# 2009-01-04       3     490.0                                 15.0
# 2009-01-05       3     490.0                                 15.0
#
#             Actual Stock - Days  Daily_Percent  Indigenous_Percent  \
# level_1
# 2009-01-01                 18.0       1.163265           20.906122
# 2009-01-02                 18.0       1.163265           20.906122
# 2009-01-03                 18.0       1.163265           20.891837
# 2009-01-04                 18.0       1.163265           20.948980
# 2009-01-05                 18.0       1.163265           20.846939
#
#             Import_Percent
# level_1
# 2009-01-01             0.0
# 2009-01-02             0.0
# 2009-01-03             0.0
# 2009-01-04             0.0
# 2009-01-05             0.0

# %%
from sklearn.model_selection import train_test_split
from time import time
import numpy as np
import matplotlib.pyplot as pl
import matplotlib.patches as mpatches
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size = 0.2, random_state = 42)
print "Training set has {} samples.".format(X_train.shape[0])
print "Testing set has {} samples.".format(X_test.shape[0])
# Out:
# Training set has 97509 samples.
# Testing set has 24378 samples.

# %%
from sklearn.metrics import fbeta_score
from sklearn.metrics import accuracy_score

def train_predict(learner, sample_size, X_train, y_train, X_test, y_test): 
    '''
    inputs:
       - learner: the learning algorithm to be trained and predicted on
       - sample_size: the size of samples (number) to be drawn from training set
       - X_train: data training set
       - y_train: label training set
       - X_test: data testing set
       - y_test: label testing set
    '''
    
    results = {}
    
    sample_size=int(sample_size)
    
    #  Fit the learner to the training data using slicing with 'sample_size'
    start = time() # Get start time
    learner.fit(X_train.iloc[:sample_size, :], y_train[:sample_size])
    end = time() # Get end time
    
    #  Calculate the training time
    results['train_time'] = end-start
        
    #  Get the predictions on the test set,
    #       then get predictions on the first 300 training samples
    start = time() # Get start time
    predictions_test = learner.predict(X_test)
    predictions_train = learner.predict(X_train.iloc[:300, :])
    end = time() # Get end time
    
    #  Calculate the total prediction time
    results['pred_time'] = end-start
            
    #  Compute accuracy on the first 300 training samples
    results['acc_train'] = accuracy_score(y_train.iloc[:300], predictions_train, sample_weight=None)
        
    #  Compute accuracy on test set
    results['acc_test'] = accuracy_score(y_test, predictions_test, sample_weight=None)
    
    #  Compute F-score on the the first 300 training samples
    results['f_train'] = fbeta_score(y_train.iloc[:300], predictions_train, beta=0.5)
        
    #  Compute F-score on the test set
    results['f_test'] = fbeta_score(y_test, predictions_test, beta=0.5)
       
    # Success
    print "{} trained on {} samples.".format(learner.__class__.__name__, sample_size)
        
    # Return the results
    return results
def evaluate(results):
    """
    Visualization code to display results of various learners.
    
    inputs:
      - learners: a list of supervised learners
      - stats: a list of dictionaries of the statistic results from 'train_predict()'
      - accuracy: The score for the naive predictor
      - f1: The score for the naive predictor
    """
  
    # Create figure
    fig, ax = plt.subplots(2, 3, figsize = (11,7))

    # Constants
    bar_width = 0.3
    colors = ['#A00000','#00A0A0','#00A000']
    
    # Super loop to plot four panels of data
    for k, learner in enumerate(results.keys()):
        for j, metric in enumerate(['train_time', 'acc_train', 'f_train', 'pred_time', 'acc_test', 'f_test']):
            for i in np.arange(3):
                
                # Creative plot code
                ax[j/3, j%3].bar(i+k*bar_width, results[learner][i][metric], width = bar_width, color = colors[k])
                ax[j/3, j%3].set_xticks([0.45, 1.45, 2.45])
                ax[j/3, j%3].set_xticklabels(["1%", "10%", "100%"])
                ax[j/3, j%3].set_xlabel("Training Set Size")
                ax[j/3, j%3].set_xlim((-0.1, 3.0))
    
    # Add unique y-labels
    ax[0, 0].set_ylabel("Time (in seconds)")
    ax[0, 1].set_ylabel("Accuracy Score")
    ax[0, 2].set_ylabel("F-score")
    ax[1, 0].set_ylabel("Time (in seconds)")
    ax[1, 1].set_ylabel("Accuracy Score")
    ax[1, 2].set_ylabel("F-score")
    
    # Add titles
    ax[0, 0].set_title("Model Training")
    ax[0, 1].set_title("Accuracy Score on Training Subset")
    ax[0, 2].set_title("F-score on Training Subset")
    ax[1, 0].set_title("Model Predicting")
    ax[1, 1].set_title("Accuracy Score on Testing Set")
    ax[1, 2].set_title("F-score on Testing Set")
    
    
    # Set y-limits for score panels
    ax[0, 1].set_ylim((0, 1))
    ax[0, 2].set_ylim((0, 1))
    ax[1, 1].set_ylim((0, 1))
    ax[1, 2].set_ylim((0, 1))

    # Create patches for the legend
    patches = []
    for i, learner in enumerate(results.keys()):
        patches.append(mpatches.Patch(color = colors[i], label = learner))
    pl.legend(handles = patches, bbox_to_anchor = (-.80, 2.53), \
               loc = 'upper center', borderaxespad = 0., ncol = 3, fontsize = 'x-large')
    
    # Aesthetics
    pl.suptitle("Performance Metrics for Three Supervised Learning Models", fontsize = 16, y = 1.10)
    pl.tight_layout()
    pl.show()

# %%
#  Import the supervised learning models from sklearn
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier

# Initialize the three models
clf_A = DecisionTreeClassifier(random_state=5)
clf_B = LogisticRegression(random_state=8)
clf_C = GradientBoostingClassifier()

#  Calculate the number of samples for 1%, 10%, and 100% of the training data
samples_1 = 0.01 * X_train.shape[0]
samples_10 = 0.1 * X_train.shape[0]
samples_100 = X_train.shape[0]

# Collect results on the learners
results = {}
for clf in [clf_A, clf_B, clf_C]:
    clf_name = clf.__class__.__name__
    results[clf_name] = {}
    for i, samples in enumerate([samples_1, samples_10, samples_100]):
        results[clf_name][i] = train_predict(clf, samples, X_train, y_train, X_test, y_test)

# Run metrics visualization for the supervised learning models chosen
evaluate(results)
# Out:
# DecisionTreeClassifier trained on 975 samples.
# DecisionTreeClassifier trained on 9750 samples.
# DecisionTreeClassifier trained on 97509 samples.
# LogisticRegression trained on 975 samples.
# LogisticRegression trained on 9750 samples.
# LogisticRegression trained on 97509 samples.
# GradientBoostingClassifier trained on 975 samples.
# GradientBoostingClassifier trained on 9750 samples.
# GradientBoostingClassifier trained on 97509 samples.
